# %% [markdown]
# # Lab 3
# ### Averaging Filters
#
# http://scikit-image.org/docs/0.13.x/api/skimage.util.html#skimage.util.random_noise
#
# http://scikit-image.org/docs/dev/api/skimage.filters.html#skimage.filters.median
#
# http://scikit-image.org/docs/dev/api/skimage.filters.html#skimage.filters.gaussian

# %%
from commonfunctions import *
import math

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dx = [-1,-1,-1,0,0,0,1,1,1]
dy = [-1,0,1,-1,0,1,-1,0,1]
def median (photo):
    temp = np.copy(photo)
    for i in range (len(photo)):
        for j in range (len(photo[i])):
            if i == 0 or j == 0 or i >= (len(photo) - 2) or j >= (len(photo[i]) - 2) :
                temp[i][j] = photo[i][j]
            else :
                neighbours = np.zeros(9)
                for k in range(9):
                    neighbours[k] = photo[i+dx[k]][j+dy[k]]
                temp[i][j] = np.median(neighbours)
                    
    return temp

# %%
img = io.imread('tiger.jpg')
gray = rgb2gray(img)
noisy = random_noise(gray,mode='s&p',amount=0.05)

# %%
'''
(1) Median Filter

'''
my_median = median (noisy)
skimage_median = median(noisy)
show_images([gray,noisy,my_median,skimage_median],['gray','noisy','my median','skimage median'])

# %%
'''
(2) Averaging Filter
'''
g1 = gaussian_filter(noisy,sigma=8)
g2 = gaussian_filter(noisy,sigma=3)
g3 = gaussian_filter(noisy,sigma=0.2)
g4 = gaussian_filter(noisy,sigma=1)
show_images([noisy,g1,g2,g3,g4],['noisy','gausian filter with sigma 8','gausian filter with sigma 3','gausian filter with sigma 0.2','0'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-b88900af2e21> in <module>
#       2 (2) Averaging Filter
#       3 '''
# ----> 4 g1 = gaussian_filter(noisy,sigma=8,length=9)
#       5 g2 = gaussian_filter(noisy,sigma=3)
#       6 g3 = gaussian_filter(noisy,sigma=0.2)
#
# TypeError: gaussian_filter() got an unexpected keyword argument 'length'
